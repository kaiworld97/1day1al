# %%
a = int(input())

# %%
b = list(range(1, a + 1))
c = []
for d in b:
    f = []
    if d % 2 == 0:
        for e in range(1, d + 1):
            # print(d, e)
            if e * 2 == d:
                f.append(e)
                f.append(d)
                break
            elif d % e == 0:
                f.append(e)
        c.append(sum(f))
    else:
        for e in range(1, int((d + 1)/2), 2):
            print(d, e)
            if e != 1 and d % e == 0:

            elif d % e == 0:
                f.append(e)
        f.append(d)
        print(f)
        c.append(sum(f))
print(sum(c))
# Out:
# [1]
# 3 1
# [1, 3]
# 5 1
# [1, 5]
# 7 1
# 7 3
# [1, 7]
# 9 1
# 9 3
# [1, 3, 9]
# 11 1
# 11 3
# 11 5
# [1, 11]
# 13 1
# 13 3
# 13 5
# [1, 13]
# 15 1
# 15 3
# 15 5
# 15 7
# [1, 3, 5, 15]
# 17 1
# 17 3
# 17 5
# 17 7
# [1, 17]
# 19 1
# 19 3
# 19 5
# 19 7
# 19 9
# [1, 19]
# 21 1
# 21 3
# 21 5
# 21 7
# 21 9
# [1, 3, 7, 21]
# 23 1
# 23 3
# 23 5
# 23 7
# 23 9
# 23 11
# [1, 23]
# 25 1
# 25 3
# 25 5
# 25 7
# 25 9
# 25 11
# [1, 5, 25]
# 27 1
# 27 3
# 27 5
# 27 7
# 27 9
# 27 11
# 27 13
# [1, 3, 9, 27]
# 29 1
# 29 3
# 29 5
# 29 7
# 29 9
# 29 11
# 29 13
# [1, 29]
# 31 1
# 31 3
# 31 5
# 31 7
# 31 9
# 31 11
# 31 13
# 31 15
# [1, 31]
# 33 1
# 33 3
# 33 5
# 33 7
# 33 9
# 33 11
# 33 13
# 33 15
# [1, 3, 11, 33]
# 35 1
# 35 3
# 35 5
# 35 7
# 35 9
# 35 11
# 35 13
# 35 15
# 35 17
# [1, 5, 7, 35]
# 37 1
# 37 3
# 37 5
# 37 7
# 37 9
# 37 11
# 37 13
# 37 15
# 37 17
# [1, 37]
# 39 1
# 39 3
# 39 5
# 39 7
# 39 9
# 39 11
# 39 13
# 39 15
# 39 17
# 39 19
# [1, 3, 13, 39]
# 41 1
# 41 3
# 41 5
# 41 7
# 41 9
# 41 11
# ...
